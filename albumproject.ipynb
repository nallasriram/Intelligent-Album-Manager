# %%
from os import access
import boto3 
import csv											
access_key_id = 'AKIAQ5O73G7DSIQ5HC66'			
secret_access_key = '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'				
client = boto3.client('rekognition',
aws_access_key_id = access_key_id , 
aws_secret_access_key = secret_access_key , 
 region_name = 'ap-south-1')											
									
def create_collection(collection_id):											
    print ('Creating collection: '+collection_id)
    response = client.create_collection(CollectionId=collection_id)
    print('Collection ARN:'+response["CollectionArn"])
    print('Status code: ' +str(response['StatusCode']))	 												
    print('Done...')											
def	main ():																				
    collection_id = 'Intelligent_Album_Faces_VIT'											
    create_collection(collection_id)
    
if (__name__== "__main__"):
    main()
# Out:
# Creating collection: Intelligent_Album_Faces_VIT
# ---------------------------------------------------------------------------
# ResourceAlreadyExistsException            Traceback (most recent call last)
# Cell In[1], line 22
#      19     create_collection(collection_id)
#      21 if (__name__== "__main__"):
# ---> 22     main()
#
# Cell In[1], line 19, in main()
#      17 def	main ():
#      18     collection_id = 'Intelligent_Album_Faces_VIT'
# ---> 19     create_collection(collection_id)
#
# Cell In[1], line 13, in create_collection(collection_id)
#      11 def create_collection(collection_id):
#      12     print ('Creating collection: '+collection_id)
# ---> 13     response = client.create_collection(CollectionId=collection_id)
#      14     print('Collection ARN:'+response["CollectionArn"])
#      15     print('Status code: ' +str(response['StatusCode']))
#
# File ~\miniconda3\lib\site-packages\botocore\client.py:508, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     504     raise TypeError(
#     505         f"{py_operation_name}() only accepts keyword arguments."
#     506     )
#     507 # The "self" in this scope is referring to the BaseClient.
# --> 508 return self._make_api_call(operation_name, kwargs)
#
# File ~\miniconda3\lib\site-packages\botocore\client.py:915, in BaseClient._make_api_call(self, operation_name, api_params)
#     913     error_code = parsed_response.get("Error", {}).get("Code")
#     914     error_class = self.exceptions.from_code(error_code)
# --> 915     raise error_class(parsed_response, operation_name)
#     916 else:
#     917     return parsed_response
#
# ResourceAlreadyExistsException: An error occurred (ResourceAlreadyExistsException) when calling the CreateCollection operation: The collection id: Intelligent_Album_Faces_VIT already exists

# %%
import boto3
access_key_id = 'AKIAQ5O73G7DSIQ5HC66'			
secret_access_key = '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'	
def add_faces_to_collection(bucket,photo,collection_id):


    
    client=boto3.client('rekognition',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key ,region_name = 'ap-south-1')
    response=client.index_faces(CollectionId=collection_id,
                                Image={'S3Object':{'Bucket':bucket,'Name':photo}},
                                ExternalImageId=photo,
                                MaxFaces=1,
                                QualityFilter="AUTO",
                                DetectionAttributes=['ALL'])

    print ('Results for ' + photo) 	
    print('Faces indexed:')						
    for faceRecord in response['FaceRecords']:
         print('  Face ID: ' + faceRecord['Face']['FaceId'])
         print('  Location: {}'.format(faceRecord['Face']['BoundingBox']))

    print('Faces not indexed:')
    for unindexedFace in response['UnindexedFaces']:
        print(' Location: {}'.format(unindexedFace['FaceDetail']['BoundingBox']))
        print(' Reasons:')
        for reason in unindexedFace['Reasons']:
            print('   ' + reason)
    return len(response['FaceRecords'])

def main():
    bucket='vitbucketalbum'
    collection_id='Intelligent_Album_Faces_VIT'
    photos=["margot_robbie.jpg","jacqueline_fernandez.jpg","hrithik_roshan.jpg","gal_gadot.jpg","chris_pine.jpg"]
    for photo in photos:
        indexed_faces_count=add_faces_to_collection(bucket,photo,collection_id)
    print("Faces indexed count: " + str(indexed_faces_count))


if __name__ == "__main__":
    main()
# Out:
# Results for margot_robbie.jpg
# Faces indexed:
#   Face ID: 003442dd-d00b-4739-9176-f6265495c9b5
#   Location: {'Width': 0.4334782660007477, 'Height': 0.558307945728302, 'Left': 0.24860379099845886, 'Top': 0.13981971144676208}
# Faces not indexed:
# Results for jacqueline_fernandez.jpg
# Faces indexed:
#   Face ID: 6663306b-ed8b-44aa-8d12-561080105295
#   Location: {'Width': 0.524909496307373, 'Height': 0.49286165833473206, 'Left': 0.18668723106384277, 'Top': 0.19263800978660583}
# Faces not indexed:
# Results for hrithik_roshan.jpg
# Faces indexed:
#   Face ID: 75f192f8-2438-4eab-84b4-3e10391fefc8
#   Location: {'Width': 0.39067506790161133, 'Height': 0.5992287993431091, 'Left': 0.2761928141117096, 'Top': 0.1957472413778305}
# Faces not indexed:
# Results for gal_gadot.jpg
# Faces indexed:
#   Face ID: 4274df4b-c2de-434c-be4a-cb58010bfbaf
#   Location: {'Width': 0.2043052613735199, 'Height': 0.5095810294151306, 'Left': 0.4211951494216919, 'Top': 0.1288198083639145}
# Faces not indexed:
# Results for chris_pine.jpg
# Faces indexed:
#   Face ID: 3d8c301e-bef2-4828-8f03-4c71db48cd94
#   Location: {'Width': 0.4964166283607483, 'Height': 0.5059847235679626, 'Left': 0.20413364470005035, 'Top': 0.1512664258480072}
# Faces not indexed:
# Faces indexed count: 1

# %%
import boto3
access_key_id = 'AKIAQ5O73G7DSIQ5HC66'			
secret_access_key = '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'	
def list_faces_in_collection(collection_id):


    maxResults=2
    faces_count=0
    tokens=True

    client=boto3.client('rekognition',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key,region_name = 'ap-south-1')
    response=client.list_faces(CollectionId=collection_id,
                               MaxResults=maxResults)

    print('Faces in collection ' + collection_id)

 
    while tokens:

        faces=response['Faces']

        for face in faces:
            print (face)
            faces_count+=1
        if 'NextToken' in response:
            nextToken=response['NextToken']
            response=client.list_faces(CollectionId=collection_id,
                                       NextToken=nextToken,MaxResults=maxResults)
        else:
            tokens=False
    return faces_count   
def main():

    collection_id='Intelligent_Album_Faces'

    faces_count=list_faces_in_collection(collection_id)
    print("faces count: " + str(faces_count))
if __name__ == "__main__":
    main()
# Out:
# Faces in collection Intelligent_Album_Faces
# {'FaceId': '32261e08-f551-48a5-8e8a-64b4c78b9341', 'BoundingBox': {'Width': 0.4334779977798462, 'Height': 0.5583080053329468, 'Left': 0.24860399961471558, 'Top': 0.13981999456882477}, 'ImageId': 'b03c979a-b4c6-3833-871c-472f91f2cef9', 'ExternalImageId': 'margot_robbie.jpg', 'Confidence': 99.99979400634766, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': '97bcb729-386e-48f4-a9e8-a4472f2485f9', 'BoundingBox': {'Width': 0.2043049931526184, 'Height': 0.5095810294151306, 'Left': 0.42119500041007996, 'Top': 0.12882000207901}, 'ImageId': 'f8a1e86b-fe41-355b-975a-6c7ad3956bea', 'ExternalImageId': 'gal_gadot.jpg', 'Confidence': 99.99949645996094, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'd3e25b67-ebe6-4df3-b428-e187ad31043d', 'BoundingBox': {'Width': 0.5249090194702148, 'Height': 0.4928619861602783, 'Left': 0.18668699264526367, 'Top': 0.19263799488544464}, 'ImageId': 'ebbe084f-1506-34e8-9367-46498e2c3988', 'ExternalImageId': 'jacqueline_fernandez.jpg', 'Confidence': 100.0, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'e01aa0b8-113d-425f-8420-c40b54cf6649', 'BoundingBox': {'Width': 0.49641698598861694, 'Height': 0.5059850215911865, 'Left': 0.204134002327919, 'Top': 0.15126599371433258}, 'ImageId': 'e2fb45f0-59a7-3695-b552-056a2cc15203', 'ExternalImageId': 'chris_pine.jpg', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# {'FaceId': 'fc2a7929-f7df-4213-9d22-f38616a96766', 'BoundingBox': {'Width': 0.39067500829696655, 'Height': 0.5992289781570435, 'Left': 0.2761929929256439, 'Top': 0.1957470029592514}, 'ImageId': '6ff59ea6-8eeb-308d-88dc-00b4acd743b4', 'ExternalImageId': 'hrithik_roshan.jpg', 'Confidence': 99.9999008178711, 'IndexFacesModelVersion': '6.0'}
# faces count: 5

# %%
import boto3

if __name__ == "__main__":
    access_key_id = 'AKIAQ5O73G7DSIQ5HC66'			
    secret_access_key = '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'	
    bucket='vitbucketalbum'
    collectionId='Intelligent_Album_Faces'
    fileNames=["margot_robbie.jpg","jacqueline_fernandez.jpg","hrithik_roshan.jpg","gal_gadot.jpg","chris_pine.jpg"]
    threshold = 70
    maxFaces=2

    client=boto3.client('rekognition',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key,region_name = 'ap-south-1')

    for fileName in fileNames:
        response=client.search_faces_by_image(CollectionId=collectionId,
                                              Image={'S3Object':{'Bucket':bucket,'Name':fileName}},
                                              FaceMatchThreshold=threshold,
                                              MaxFaces=maxFaces)

                                
        faceMatches=response['FaceMatches']
        print ('Matching faces')
        for match in faceMatches:
                print ('FaceId:' + match['Face']['FaceId'])
                print ('Similarity: ' + "{:.2f}".format(match['Similarity']) + "%")
                print
# Out:
# Matching faces
# FaceId:32261e08-f551-48a5-8e8a-64b4c78b9341
# Similarity: 100.00%
# Matching faces
# FaceId:d3e25b67-ebe6-4df3-b428-e187ad31043d
# Similarity: 100.00%
# Matching faces
# FaceId:fc2a7929-f7df-4213-9d22-f38616a96766
# Similarity: 100.00%
# Matching faces
# FaceId:97bcb729-386e-48f4-a9e8-a4472f2485f9
# Similarity: 100.00%
# Matching faces
# FaceId:e01aa0b8-113d-425f-8420-c40b54cf6649
# Similarity: 100.00%

# %%
import boto3 
access_key_id = 'AKIAQ5O73G7DSIQ5HC66'			
secret_access_key = '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'	
client=boto3.client('rekognition',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key,region_name = 'ap-south-1')
s3 = boto3.client('s3',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key,region_name = 'ap-south-1')
def main ():
    bucket= 'vitbucketalbum'										
    collection_id = 'Intelligent_Album_Faces'
    fileNames = ['test1.jpg','test2.jpg','test3.jpg','test4.jpg','test5.jpg','test6.jpg']										
									
    threshold = 70										
    maxFaces = 2
    for fileName in fileNames:
        response=client.search_faces_by_image(CollectionId=collection_id,
                                Image={'S3Object':{'Bucket':bucket,'Name':fileName}},
                                FaceMatchThreshold=threshold,
                                MaxFaces=maxFaces)
        faceMatches=response['FaceMatches']
        print ('Matching faces')
        for match in faceMatches:
                print ('FaceId: ' + match['Face']['FaceId'])
                print ('External Id: ' +match['Face']['ExternalImageId'])
                print ('Similarity: ' + "{:.2f}".format(match['Similarity']) + "%")
                copy_from = str(bucket+'/'+fileName)																			
                move_to = str(match['Face']["ExternalImageId"][:-4]+'/' +fileName)								
                s3.copy_object(Bucket=bucket, CopySource=copy_from, Key=move_to)																				
                print("successfully moved to " +move_to)
if (__name__== "__main__"):
    main()
# Out:
# Matching faces
# FaceId: 32261e08-f551-48a5-8e8a-64b4c78b9341
# External Id: margot_robbie.jpg
# Similarity: 70.56%
# successfully moved to margot_robbie/test1.jpg
# Matching faces
# FaceId: fc2a7929-f7df-4213-9d22-f38616a96766
# External Id: hrithik_roshan.jpg
# Similarity: 99.83%
# successfully moved to hrithik_roshan/test2.jpg
# Matching faces
# FaceId: d3e25b67-ebe6-4df3-b428-e187ad31043d
# External Id: jacqueline_fernandez.jpg
# Similarity: 99.75%
# successfully moved to jacqueline_fernandez/test3.jpg
# Matching faces
# FaceId: 97bcb729-386e-48f4-a9e8-a4472f2485f9
# External Id: gal_gadot.jpg
# Similarity: 99.93%
# successfully moved to gal_gadot/test4.jpg
# Matching faces
# FaceId: e01aa0b8-113d-425f-8420-c40b54cf6649
# External Id: chris_pine.jpg
# Similarity: 100.00%
# successfully moved to chris_pine/test5.jpg
# Matching faces
# FaceId: 97bcb729-386e-48f4-a9e8-a4472f2485f9
# External Id: gal_gadot.jpg
# Similarity: 99.87%
# successfully moved to gal_gadot/test6.jpg

# %%
import os
import threading
from typing import Text
from flask import Flask, request, render_template
from gevent.pywsgi import WSGIServer
import boto3
access_key_id = 'AKIAQ5O73G7DSIQ5HC66'			
secret_access_key = '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'	
client=boto3.client('rekognition',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key,region_name = 'ap-south-1')
s3 = boto3.client('s3',aws_access_key_id = access_key_id ,aws_secret_access_key = secret_access_key,region_name = 'ap-south-1')
app = Flask(__name__)
@app.route('/')
def index():
    return render_template('base.html')

@app.route('/index.html',methods = ['GET','POST'])
def upload():
    if request.method == 'POST':
        f = request.files['image']
        print('Image name : ',f)
        print("current path")
        base_path = os.path.dirname(__file__)
        print("current_path",base_path)
        filepath = os.path.join(base_path,'uploads',f.filename)
        print("upload folder is ",filepath)
        f.save(filepath)

        text = main(filepath)
    return text
# @app.route('/pred',methods=['GET','POST'])
# def pred():
#     if request.method=='POST':
#         some = request.files['image']
    # return render_template('base.html',d=some)
def main(filepath):
    bucket= 'vitbucketalbum'										
    collection_id = 'Intelligent_Album_Faces'
    filename = filepath
    relative_filename = os.path.split(filepath)[1]
    fileNames=[relative_filename]
    s3.upload_file(filename,bucket,relative_filename)
    print("file Uploaded")

    threshold = 70										
    maxFaces = 2
    for fileName in fileNames:
        response=client.search_faces_by_image(CollectionId=collection_id,
                                Image={'S3Object':{'Bucket':bucket,'Name':fileName}},
                                FaceMatchThreshold=threshold,
                                MaxFaces=maxFaces)
        faceMatches=response['FaceMatches']
        print ('Matching faces')
        for match in faceMatches:
            print ('FaceId: ' + match['Face']['FaceId'])
            print ('External Id: ' +match['Face']['ExternalImageId'])
            print ('Similarity: ' + "{:.2f}".format(match['Similarity']) + "%")
            copy_from = str(bucket+'/'+fileName)																			
            move_to = str(match['Face']["ExternalImageId"][:-4]+'/' +fileName)
            recognized_person_name = str(match['Face']['ExternalImageId'][:-4])								
            s3.copy_object(Bucket=bucket, CopySource=copy_from, Key=move_to)																				
            print("successfully moved to " +move_to)
            f = str(match['Face']['ExternalImageId']) 
        
        return render_template('index.html',data=f,d=recognized_person_name)
        # return move_to
if __name__ == "__main__":
    app.run(debug=True, threaded = False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\srira\miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
